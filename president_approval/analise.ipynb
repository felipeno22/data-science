# %%
# Passo a passo
# Passo 1: Importar base de dados
#!pip install pandas numpy openpyxl nbformat plotly
import pandas as pd

tabela=pd.read_csv("president_approval_polls.csv")
display(tabela)
# Out:
#       poll_id  pollster_id                      pollster sponsor_ids  \
# 0       88561         1562  Redfield & Wilton Strategies         NaN
# 1       88528         1478                  Research Co.         NaN
# 2       88527          568                        YouGov        1213
# 3       88527          568                        YouGov        1213
# 4       88527          568                        YouGov        1213
# ...       ...          ...                           ...         ...
# 4974    74248          241                         Ipsos          71
# 4975    74248          241                         Ipsos          71
# 4976    74327          568                        YouGov        1213
# 4977    74247          399                     Rasmussen        1585
# 4978    74272         1189               Morning Consult         NaN
#
#         sponsors                  display_name  pollster_rating_id  \
# 0            NaN  Redfield & Wilton Strategies                 562
# ...
